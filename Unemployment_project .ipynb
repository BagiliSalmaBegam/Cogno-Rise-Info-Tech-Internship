# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\DELL\Desktop\EDA PROJECT\Unemployment in India.xlsx")

# %%
data
# Out:
#              Region         Date  Frequency  Unemployment  Employed  Labour  \
# 0    Andhra Pradesh   31-05-2019    Monthly          3.65  11999139   43.24
# 1    Andhra Pradesh   30-06-2019    Monthly          3.05  11755881   42.05
# 2    Andhra Pradesh   31-07-2019    Monthly          3.75  12086707   43.50
# 3    Andhra Pradesh   31-08-2019    Monthly          3.32  12285693   43.97
# 4    Andhra Pradesh   30-09-2019    Monthly          5.17  12256762   44.68
# ..              ...          ...        ...           ...       ...     ...
# 735     West Bengal   29-02-2020    Monthly          7.55  10871168   44.09
# 736     West Bengal   31-03-2020    Monthly          6.67  10806105   43.34
# 737     West Bengal   30-04-2020    Monthly         15.63   9299466   41.20
# 738     West Bengal   31-05-2020    Monthly         15.22   9240903   40.67
# 739     West Bengal   30-06-2020    Monthly          9.86   9088931   37.57
#
#       Area
# 0    Rural
# 1    Rural
# 2    Rural
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Region                                740 non-null    object
#  1    Date                                 740 non-null    object
#  2    Frequency                            740 non-null    object
#  3    Estimated Unemployment Rate          740 non-null    float64
#  4    Estimated Employed                   740 non-null    int64
#  5    Estimated Labour Participation Rate  740 non-null    float64
#  6   Area                                  740 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 40.6+ KB

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate   Estimated Employed  \
# count                    740.000000         7.400000e+02
# mean                      11.787946         7.204460e+06
# std                       10.721298         8.087988e+06
# min                        0.000000         4.942000e+04
# 25%                        4.657500         1.190404e+06
# 50%                        8.350000         4.744178e+06
# 75%                       15.887500         1.127549e+07
# max                       76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate
# count                            740.000000
# mean                              42.630122
# std                                8.111094
# min                               13.330000
# 25%                               38.062500
# 50%                               41.160000
# 75%                               45.505000
# max                               72.570000

# %%
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019    Monthly                          3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                          3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                          3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                          3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                          5.17
# ..              ...          ...        ...                           ...
# 735     West Bengal   29-02-2020    Monthly                          7.55
# 736     West Bengal   31-03-2020    Monthly                          6.67
# 737     West Bengal   30-04-2020    Monthly                         15.63
# 738     West Bengal   31-05-2020    Monthly                         15.22
# 739     West Bengal   30-06-2020    Monthly                          9.86
#
#       Estimated Employed   Estimated Labour Participation Rate   Area
# ...

# %%
data["Area"].value_counts().plot(kind="pie",autopct="%1.2f")
# Out:
# <Axes: ylabel='count'>

# %%
data["Region"].value_counts().plot(kind="pie",autopct="%1.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(data=data)
plt.xticks(rotation=90)
plt.show()

# %%
data.head()
# Out:
#            Region         Date  Frequency  Unemployment  Employed  Labour  \
# 0  Andhra Pradesh   31-05-2019    Monthly          3.65  11999139   43.24
# 1  Andhra Pradesh   30-06-2019    Monthly          3.05  11755881   42.05
# 2  Andhra Pradesh   31-07-2019    Monthly          3.75  12086707   43.50
# 3  Andhra Pradesh   31-08-2019    Monthly          3.32  12285693   43.97
# 4  Andhra Pradesh   30-09-2019    Monthly          5.17  12256762   44.68
#
#     Area
# 0  Rural
# 1  Rural
# 2  Rural
# 3  Rural
# 4  Rural

# %%
data["Unemployment"].plot(kind="box",
               color="#0e0f0f",
               figsize= (8,4),
              xlabel="Unemployment",
              title="box-plot of Unemployment") #don't consider as outlier it is ture outlayers
# Out:
# <Axes: title={'center': 'box-plot of Unemployment'}, xlabel='Unemployment'>

# %%
sns.countplot(data=data,x="Region")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=data,x="Unemployment",y="Employed") #storng weak relation
# Out:
# <Axes: xlabel='Unemployment', ylabel='Employed'>

# %%
data.head()
# Out:
#            Region         Date  Frequency  Unemployment  Employed  Labour  \
# 0  Andhra Pradesh   31-05-2019    Monthly          3.65  11999139   43.24
# 1  Andhra Pradesh   30-06-2019    Monthly          3.05  11755881   42.05
# 2  Andhra Pradesh   31-07-2019    Monthly          3.75  12086707   43.50
# 3  Andhra Pradesh   31-08-2019    Monthly          3.32  12285693   43.97
# 4  Andhra Pradesh   30-09-2019    Monthly          5.17  12256762   44.68
#
#     Area
# 0  Rural
# 1  Rural
# 2  Rural
# 3  Rural
# 4  Rural

# %% [markdown]
# Conclusion1: There is strong weak co-relation between the Estimated Unemployment and Estimated Employed
#
#
# Conclusion2: And outliers are true outliers
